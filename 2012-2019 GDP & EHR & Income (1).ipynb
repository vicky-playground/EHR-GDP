# %% [markdown]
# # Clean and display the two datasets:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# load GDP dataset
df_GDP = pd.read_csv('GDP_CA_2001_2020.csv')
df_GDP['GeoName'] = df_GDP['GeoName'].str.rstrip(', CA')
df_GDP.drop(df_GDP.tail(4).index,inplace=True) # drop last n rows
df_GDP = df_GDP.drop(['GeoFIPS','Region','TableName','LineCode','IndustryClassification'],axis=1)
df_GDP = df_GDP[df_GDP.Description == 'Current-dollar GDP (thousands of current dollars)']
df_GDP = df_GDP.drop(df_GDP.columns[3:14],axis=1)
df_GDP = df_GDP.dropna()
df_GDP
# Out:
#              GeoName                                        Description  \
# 2         California  Current-dollar GDP (thousands of current dollars)
# 5            Alameda  Current-dollar GDP (thousands of current dollars)
# 8             Alpine  Current-dollar GDP (thousands of current dollars)
# 11            Amador  Current-dollar GDP (thousands of current dollars)
# 14             Butte  Current-dollar GDP (thousands of current dollars)
# 17         Calaveras  Current-dollar GDP (thousands of current dollars)
# 20            Colusa  Current-dollar GDP (thousands of current dollars)
# 23      Contra Costa  Current-dollar GDP (thousands of current dollars)
# 26         Del Norte  Current-dollar GDP (thousands of current dollars)
# 29         El Dorado  Current-dollar GDP (thousands of current dollars)
# 32            Fresno  Current-dollar GDP (thousands of current dollars)
# 35             Glenn  Current-dollar GDP (thousands of current dollars)
# 38          Humboldt  Current-dollar GDP (thousands of current dollars)
# 41          Imperial  Current-dollar GDP (thousands of current dollars)
# 44              Inyo  Current-dollar GDP (thousands of current dollars)
# 47              Kern  Current-dollar GDP (thousands of current dollars)
# 50             Kings  Current-dollar GDP (thousands of current dollars)
# 53              Lake  Current-dollar GDP (thousands of current dollars)
# 56            Lassen  Current-dollar GDP (thousands of current dollars)
# 59       Los Angeles  Current-dollar GDP (thousands of current dollars)
# 62            Madera  Current-dollar GDP (thousands of current dollars)
# 65             Marin  Current-dollar GDP (thousands of current dollars)
# 68          Mariposa  Current-dollar GDP (thousands of current dollars)
# 71         Mendocino  Current-dollar GDP (thousands of current dollars)
# 74            Merced  Current-dollar GDP (thousands of current dollars)
# 77             Modoc  Current-dollar GDP (thousands of current dollars)
# 80              Mono  Current-dollar GDP (thousands of current dollars)
# 83          Monterey  Current-dollar GDP (thousands of current dollars)
# 86              Napa  Current-dollar GDP (thousands of current dollars)
# 89            Nevada  Current-dollar GDP (thousands of current dollars)
# 92            Orange  Current-dollar GDP (thousands of current dollars)
# 95            Placer  Current-dollar GDP (thousands of current dollars)
# 98            Plumas  Current-dollar GDP (thousands of current dollars)
# 101        Riverside  Current-dollar GDP (thousands of current dollars)
# 104       Sacramento  Current-dollar GDP (thousands of current dollars)
# 107       San Benito  Current-dollar GDP (thousands of current dollars)
# 110   San Bernardino  Current-dollar GDP (thousands of current dollars)
# 113        San Diego  Current-dollar GDP (thousands of current dollars)
# 116    San Francisco  Current-dollar GDP (thousands of current dollars)
# 119      San Joaquin  Current-dollar GDP (thousands of current dollars)
# 122  San Luis Obispo  Current-dollar GDP (thousands of current dollars)
# 161  4.432450e+05
# 164  1.898016e+07
# 167  2.600257e+06
# 170  5.321897e+07
# 173  1.591999e+07
# 176  3.544698e+06

# %%
# load EHR dataset
df_EHR = pd.read_csv('EHR_Incentive_Program_Payments_-_Providers.csv')
df_EHR = df_EHR.drop(df_EHR.columns[0:9], axis=1)
df_EHR = df_EHR.drop(df_EHR.columns[1:3], axis=1)
df_EHR = df_EHR.drop(['Payment__1','Payment_Cr','Payee_Name','Payee_NPI','total_rece','Latitude','Longitude','Program_Ye'],axis=1)
df_EHR = df_EHR.dropna()
df_EHR
# Out:
#            Business_1  Payment_Ye  total_paym
# 0          Sacramento        2019     38250.0
# 1             Alameda        2014     21250.0
# 2        Contra Costa        2016     21250.0
# 3      San Bernardino        2015     29750.0
# 4              Orange        2014     21250.0
# ...               ...         ...         ...
# 25686     Los Angeles        2012     21250.0
# 25687     Los Angeles        2016     29750.0
# 25688   San Francisco        2017     21250.0
# 25689     Los Angeles        2013     21250.0
# 25690       El Dorado        2013     21250.0
#
# [25691 rows x 3 columns]

# %% [markdown]
# # Aggregate the datasets

# %%
df_GDP = df_GDP.groupby(['GeoName','Description','Unit']).sum().reset_index()
df_GDP.head(5)
# Out:
#      GeoName                                        Description  \
# 0    Alameda  Current-dollar GDP (thousands of current dollars)
# 1     Alpine  Current-dollar GDP (thousands of current dollars)
# 2     Amador  Current-dollar GDP (thousands of current dollars)
# 3      Butte  Current-dollar GDP (thousands of current dollars)
# 4  Calaveras  Current-dollar GDP (thousands of current dollars)
#
#                    Unit        2012         2013         2014         2015  \
# 0  Thousands of dollars  95749481.0  100521444.0  105936777.0  115791781.0
# 1  Thousands of dollars     95294.0      93927.0     102705.0     108503.0
# 2  Thousands of dollars   1365613.0    1440258.0    1488434.0    1551133.0
# 3  Thousands of dollars   7363012.0    7602095.0    7634930.0    8041364.0
# 4  Thousands of dollars   1050964.0    1044218.0    1172626.0    1246769.0
#
#           2016         2017         2018         2019         2020
# 0  121053460.0  129028899.0  136168877.0  141888634.0  139313240.0
# 1     109263.0     110843.0     114055.0     121948.0     112415.0
# 2    1617941.0    1732487.0    1786296.0    1870309.0    1848108.0
# 3    8649007.0    9189787.0    9500527.0    9893227.0    9461454.0
# 4    1362303.0    1442782.0    1415632.0    1661687.0    1579783.0

# %%
df_EHR = df_EHR.groupby(['Business_1','Payment_Ye']).sum().reset_index()
df_EHR.tail()
# Out:
#     Business_1  Payment_Ye  total_paym
# 454       Yuba        2014    255000.0
# 455       Yuba        2015     76500.0
# 456       Yuba        2017    552500.0
# 457       Yuba        2018    187000.0
# 458       Yuba        2019     63750.0

# %% [markdown]
# # Reshape DataFrame from wide format to long format

# %%
year_list = df_GDP.columns[3:]
df_GDP = pd.melt(df_GDP, id_vars=['GeoName','Description','Unit'], value_vars=year_list) #Pandas.melt() unpivots a DataFrame from wide format to long format
df_GDP.head()
# Out:
#      GeoName                                        Description  \
# 0    Alameda  Current-dollar GDP (thousands of current dollars)
# 1     Alpine  Current-dollar GDP (thousands of current dollars)
# 2     Amador  Current-dollar GDP (thousands of current dollars)
# 3      Butte  Current-dollar GDP (thousands of current dollars)
# 4  Calaveras  Current-dollar GDP (thousands of current dollars)
#
#                    Unit variable       value
# 0  Thousands of dollars     2012  95749481.0
# 1  Thousands of dollars     2012     95294.0
# 2  Thousands of dollars     2012   1365613.0
# 3  Thousands of dollars     2012   7363012.0
# 4  Thousands of dollars     2012   1050964.0

# %% [markdown]
# # Combine the two datasets

# %%
df_GDP["variable"]
# Out:
# 0      2012
# 1      2012
# 2      2012
# 3      2012
# 4      2012
#        ...
# 526    2020
# 527    2020
# 528    2020
# 529    2020
# 530    2020
# Name: variable, Length: 531, dtype: object

# %%
df_EHR['Payment_Ye']
# Out:
# 0      2012
# 1      2013
# 2      2014
# 3      2015
# 4      2016
#        ...
# 454    2014
# 455    2015
# 456    2017
# 457    2018
# 458    2019
# Name: Payment_Ye, Length: 459, dtype: int64

# %%
df_EHR['Payment_Ye'] = df_EHR['Payment_Ye'].apply(lambda x: str(x))

# %%
df_GDP = df_GDP[df_GDP["variable"]!="2020"]
df_GDP["variable"]
# Out:
# 0      2012
# 1      2012
# 2      2012
# 3      2012
# 4      2012
#        ...
# 467    2019
# 468    2019
# 469    2019
# 470    2019
# 471    2019
# Name: variable, Length: 472, dtype: object

# %%
df = df_GDP.merge(df_EHR, how='inner', left_on=['GeoName', 'variable'], right_on=['Business_1', 'Payment_Ye'])
df.head()
# Out:
#         GeoName                                        Description  \
# 0       Alameda  Current-dollar GDP (thousands of current dollars)
# 1        Amador  Current-dollar GDP (thousands of current dollars)
# 2         Butte  Current-dollar GDP (thousands of current dollars)
# 3        Colusa  Current-dollar GDP (thousands of current dollars)
# 4  Contra Costa  Current-dollar GDP (thousands of current dollars)
#
#                    Unit variable       value    Business_1 Payment_Ye  \
# 0  Thousands of dollars     2012  95749481.0       Alameda       2012
# 1  Thousands of dollars     2012   1365613.0        Amador       2012
# 2  Thousands of dollars     2012   7363012.0         Butte       2012
# 3  Thousands of dollars     2012   1197262.0        Colusa       2012
# 4  Thousands of dollars     2012  62207407.0  Contra Costa       2012
#
#    total_paym
# 0   5581667.0
# 1     63750.0
# 2    637500.0
# 3     63750.0
# 4    297500.0

# %% [markdown]
# # Application of Linear Regression (Linear regression is suited for estimating continuous values)
# ## Linear regression model fit line¶: The plot shows us how well we are able to fit the relationship between the GDP value and the total payment of EHR.

# %%
# ================================================
# Build the model
# ================================================

# Training data
X = df.loc[:,["value"]]  # features matrix
y = df.loc[:,'total_paym']  # target (response) matix

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=100)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import seaborn as sns
sns.regplot(x='value', y='total_paym', data=df, ci=None, scatter_kws={'s':100, 'facecolor':'red'})
# Out:
# <AxesSubplot: xlabel='value', ylabel='total_paym'>

# %% [markdown]
# # Predicting test set result

# %%
y_pred = model.predict(X_test)

# Comparing the test values and the predicted values
comparison_df = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
comparison_df
# Out:
#          Actual     Predicted
# 121    89250.00  1.644085e+05
# 352   429250.00  1.802565e+05
# 96    607750.00  6.960413e+05
# 43    184167.00  2.218900e+05
# 125   131750.00  1.457568e+05
# ..          ...           ...
# 60    178500.00  1.613405e+05
# 247  1334500.00  9.855817e+05
# 84   4247168.01  6.058579e+06
# 342  4364750.34  2.978872e+06
# 80   3232833.34  2.277137e+06
#
# [124 rows x 2 columns]

# %%
# Checking the residuals
residuals = y_test - y_pred
residuals
# Out:
# 121   -7.515847e+04
# 352    2.489935e+05
# 96    -8.829128e+04
# 43    -3.772302e+04
# 125   -1.400681e+04
#            ...
# 60     1.715953e+04
# 247    3.489183e+05
# 84    -1.811411e+06
# 342    1.385879e+06
# 80     9.556962e+05
# Name: total_paym, Length: 124, dtype: float64

# %%
# Comparing the test data and the predicted values with a scatter plot
sns.scatterplot(x=y_test, y = y_pred, s=140)
plt.xlabel('y_test data')
plt.ylabel('Predictions')

# The values seem to align linearly, which shows that the model is acceptable.
# Out:
# Text(0, 0.5, 'Predictions')

# %% [markdown]
# # Quantify the strength of relationship with correaltion(R)

# %% [markdown]
# Low value of GDP tends to be pair with relatively low value of EHR payment, and vice versa

# %%
model.coef_
# The coefficient shows that, on average, the value increased by approximately  0.03216984 points for every total_paym the GOV subsidized
# Out:
# array([0.03147051])

# %% [markdown]
# # check the coefficients, R2, Adjusted R2, F statistics and P values
# P value: The probability that randomly drawn points will result in the similarly strong relationship, so the smaller the p-value, the more confidence we have in the predictions we make with the line.

# %%
# Rebuild the model using OLS (Ordinary Least Squares)

# Add a constant to get an intercept
X_std_sm = sm.add_constant(X_train)
# create a fitted model
data_OLS_result = sm.OLS(y_train,X_std_sm).fit() 
data_OLS_result.params.sort_values(ascending=False) 
print(data_OLS_result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             total_paym   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     1429.
# Date:                Wed, 09 Nov 2022   Prob (F-statistic):          3.01e-113
# Time:                        02:36:03   Log-Likelihood:                -4500.5
# No. Observations:                 288   AIC:                             9005.
# Df Residuals:                     286   BIC:                             9012.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.272e+05   9.72e+04      1.309      0.192   -6.41e+04    3.19e+05
# value          0.0315      0.001     37.800      0.000       0.030       0.033
# ==============================================================================
# Omnibus:                       73.285   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              982.836
# Skew:                           0.571   Prob(JB):                    3.80e-214
# Kurtosis:                      11.978   Cond. No.                     1.30e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Check the distribution of the error terms
# In linear regression we assume that the error term follows normal distribution. So we have to check this assumption before we can use the model for making predictions. We check this by looking at the histogram of the error term visually, making sure that the error terms are normally distributed around zero and that the left and right side are broadly similar.

# %%
fig = plt.figure()
y_prediction = data_OLS_result.predict(X_std_sm)
sns.distplot((y_train - y_prediction), bins = 20)
fig.suptitle('Error Terms', fontsize = 16)
plt.show()
# Out:
# /var/folders/3f/0c48rx816935875jnxcqj5sr0000gn/T/ipykernel_57388/451520093.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_train - y_prediction), bins = 20)

# %% [markdown]
# in the case of regression against a single variable, don't worry about the condition number UNLESS you care about the sensitivity of your y-intercept to the input data.
# Ref: https://stats.stackexchange.com/questions/243000/cause-of-a-high-condition-number-in-a-python-statsmodels-regression

# %%
# Calculate the VIF (Variance Importance Factor) 
# small VIF values indicates low correlation among variables under ideal conditions VIF<3.
from statsmodels.stats.outliers_influence import variance_inflation_factor
data_VIF = pd.DataFrame()
data_VIF['variable'] = X_std_sm.columns
number_of_variables = X_std_sm.shape[1]
data_VIF['VIF'] = [variance_inflation_factor(X_std_sm.values, i) for i in range(number_of_variables)]
data_VIF.sort_values(by="VIF", ascending=False)
# Out:
#   variable       VIF
# 0    const  1.232439
# 1    value  1.000000

# %% [markdown]
# # Evaluating linear regression models

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test, y_pred)
mse=mean_squared_error(y_test, y_pred)
# Printing the metrics
print('R2 square:',r2_score(y_test, y_pred))
print('MAE: ', mae) # Mean Absolute Error
print('MSE: ', mse) # Mean Squared Error
# Out:
# R2 square: 0.7783121822731354
# MAE:  814278.4235921368
# MSE:  4068752154896.4033

# %% [markdown]
# ## Root Mean Squared Error(RMSE)

# %%
from sklearn.metrics import mean_squared_error
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 2017114.8095476378

# %%
print("RMSE",np.log(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# RMSE 14.517178736262194

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print(r2)
# Out:
# 0.7783121822731354

# %% [markdown]
# # Comparing machine learning models

# %% [markdown]
# # Application of Decision Tree regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics

dt_regressor = DecisionTreeRegressor(random_state = 0)
dt_regressor.fit(X_train, y_train)
#Predicting using test set 
y_pred = dt_regressor.predict(X_test)
mae=metrics.mean_absolute_error(y_test, y_pred)
mse=metrics.mean_squared_error(y_test, y_pred)
# Printing the metrics
print('Suppport Vector Regression Accuracy: ', dt_regressor.score(X_test,y_test))
print('R2 square:',metrics.r2_score(y_test, y_pred))
print('MAE: ', mae)
print('MSE: ', mse)
# Out:
# Suppport Vector Regression Accuracy:  0.6278202145879272
# R2 square: 0.6278202145879272
# MAE:  1082904.6541129034
# MSE:  6830809737005.881

# %% [markdown]
# # Application of Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor(n_estimators = 300 ,  random_state = 0)
rf_regressor.fit(X_train,y_train)
#Predicting the SalePrices using test set 
y_pred = rf_regressor.predict(X_test)
mae=metrics.mean_absolute_error(y_test, y_pred)
mse=metrics.mean_squared_error(y_test, y_pred)
# Printing the metrics
print('Suppport Vector Regression Accuracy: ', rf_regressor.score(X_test,y_test))
print('R2 square:',metrics.r2_score(y_test, y_pred))
print('MAE: ', mae)
print('MSE: ', mse)
# Out:
# Suppport Vector Regression Accuracy:  0.6615072222292644
# R2 square: 0.6615072222292644
# MAE:  1021944.8034459684
# MSE:  6212534514045.389

# %% [markdown]
# # Application of Support Vector Regression

# %%
from sklearn.svm import SVR
regressor= SVR(kernel='rbf')
regressor.fit(X_train,y_train)
y_pred_svm=regressor.predict(X_test)
#y_pred_svm = cross_val_predict(regressor, x, y)
mae=metrics.mean_absolute_error(y_test, y_pred_svm)
mse=metrics.mean_squared_error(y_test, y_pred_svm)
# Printing the metrics
print('Suppport Vector Regression Accuracy: ', regressor.score(X_test,y_test))
print('R2 square:',metrics.r2_score(y_test, y_pred_svm))
print('MAE: ', mae)
print('MSE: ', mse)
# Out:
# Suppport Vector Regression Accuracy:  -0.0516203442712313
# R2 square: -0.0516203442712313
# MAE:  1389040.2478050007
# MSE:  19300936721557.87

# %% [markdown]
# # Random Sample Consensus(RANSAC) Regression

# %% [markdown]
# Random sample consensus (RANSAC) is an iterative method to estimate parameters of a mathematical model from a set of observed data that contains outliers, when outliers are to be accorded no influence on the values of the estimates. Therefore, it also can be interpreted as an outlier detection method.

# %%
from sklearn.linear_model import RANSACRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
 

model = RANSACRegressor(base_estimator=LinearRegression(), max_trials=100)
model.fit(X_train, y_train)

test_pred = model.predict(X_test)
#train_pred = model.predict(X_train)

mae=metrics.mean_absolute_error(y_test, test_pred)
mse=metrics.mean_squared_error(y_test, test_pred)



print('Suppport Vector Regression Accuracy: ', model.score(X_test,y_test))
print('R2 square:',metrics.r2_score(y_test, y_pred))
print('MAE: ', mae)
print('MSE: ', mse)
print('Mean MAE: %.3f (%.3f)' % (mean(results), std(results)))
# Out:
# Suppport Vector Regression Accuracy:  0.7724720440689261
# R2 square: 0.6615072222292644
# MAE:  798070.3988996836
# MSE:  4175939257674.1743
# Mean MAE: 1068697.814 (382949.319)
# /Users/vicky/.pyenv/versions/3.9.6/lib/python3.9/site-packages/sklearn/linear_model/_ransac.py:320: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.1 and will be removed in 1.3.
#   warnings.warn(

# %% [markdown]
#  # EHR spending correlation with per-capita income analysis

# %%
# load GDP dataset
df_income = pd.read_csv('County_Revenues_Per_Capita.csv')
df_income
# Out:
#      Entity Name  Fiscal Year Total Revenues Estimated Population  \
# 0        Alameda         2020  3,752,904,942            1,670,834
# 1        Alameda         2019  3,609,996,506            1,669,301
# 2        Alameda         2018  3,057,808,028            1,660,202
# 3        Alameda         2017  2,949,248,612            1,645,359
# 4        Alameda         2016  2,638,195,535            1,627,865
# ...          ...          ...            ...                  ...
# 1021        Yuba         2007    126,481,406               70,745
# 1022        Yuba         2006    120,119,483               69,827
# 1023        Yuba         2005    100,090,654               66,734
# 1024        Yuba         2004     96,186,352               64,840
# 1025        Yuba         2003    103,401,286               62,847
#
#      Revenues Per Capita
# 0                  2,246
# 1                  2,163
# 2                  1,842
# 3                  1,792
# 4                  1,621
# ...                  ...
# 1021               1,788
# 1022               1,720
# 1023               1,500
# 1024               1,483
# 1025               1,645
#
# [1026 rows x 5 columns]

# %%
df_income["Fiscal Year"]
# Out:
# 0       2020
# 1       2019
# 2       2018
# 3       2017
# 4       2016
#         ...
# 1021    2007
# 1022    2006
# 1023    2005
# 1024    2004
# 1025    2003
# Name: Fiscal Year, Length: 1026, dtype: int64

# %%
df_income = df_income[(df_income["Fiscal Year"]>=2012) & (df_income["Fiscal Year"]<=2019)]
df_income["Fiscal Year"]
# Out:
# 1       2019
# 2       2018
# 3       2017
# 4       2016
# 5       2015
#         ...
# 1012    2016
# 1013    2015
# 1014    2014
# 1015    2013
# 1016    2012
# Name: Fiscal Year, Length: 456, dtype: int64

# %%
df_income['Fiscal Year'] = df_income['Fiscal Year'].apply(lambda x: str(x))

# %%
df_2 = df_income.merge(df_EHR, how='inner', left_on=['Entity Name', 'Fiscal Year'], right_on=['Business_1', 'Payment_Ye'])
df_2.head()
# Out:
#   Entity Name Fiscal Year Total Revenues Estimated Population  \
# 0     Alameda        2019  3,609,996,506            1,669,301
# 1     Alameda        2018  3,057,808,028            1,660,202
# 2     Alameda        2017  2,949,248,612            1,645,359
# 3     Alameda        2016  2,638,195,535            1,627,865
# 4     Alameda        2015  2,459,908,014            1,594,569
#
#   Revenues Per Capita Business_1 Payment_Ye  total_paym
# 0               2,163    Alameda       2019  6739083.67
# 1               1,842    Alameda       2018  2549750.00
# 2               1,792    Alameda       2017  5737500.00
# 3               1,621    Alameda       2016  3476500.00
# 4               1,543    Alameda       2015  4862000.00

# %%
# convert string with comma as thousands separator to Number
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
df_2['Estimated Population']  = df_2['Estimated Population'].apply(lambda x: locale.atoi(x)) 
df_2['Revenues Per Capita']  = df_2['Revenues Per Capita'].apply(lambda x: locale.atoi(x)) 
df_2.head()
# Out:
#   Entity Name Fiscal Year Total Revenues  Estimated Population  \
# 0     Alameda        2019  3,609,996,506               1669301
# 1     Alameda        2018  3,057,808,028               1660202
# 2     Alameda        2017  2,949,248,612               1645359
# 3     Alameda        2016  2,638,195,535               1627865
# 4     Alameda        2015  2,459,908,014               1594569
#
#    Revenues Per Capita Business_1 Payment_Ye  total_paym
# 0                 2163    Alameda       2019  6739083.67
# 1                 1842    Alameda       2018  2549750.00
# 2                 1792    Alameda       2017  5737500.00
# 3                 1621    Alameda       2016  3476500.00
# 4                 1543    Alameda       2015  4862000.00

# %%
# calculate the per capita payment from EHR 
df_2["Subsidy Per Capita"] = (df_2["total_paym"]//df_2["Estimated Population"])
df_2.head(10)
# Out:
#   Entity Name Fiscal Year Total Revenues  Estimated Population  \
# 0     Alameda        2019  3,609,996,506               1669301
# 1     Alameda        2018  3,057,808,028               1660202
# 2     Alameda        2017  2,949,248,612               1645359
# 3     Alameda        2016  2,638,195,535               1627865
# 4     Alameda        2015  2,459,908,014               1594569
# 5     Alameda        2014  2,448,572,609               1573254
# 6     Alameda        2013  2,366,341,383               1548681
# 7     Alameda        2012  2,317,607,829               1532137
# 8      Amador        2017     73,472,682                 38382
# 9      Amador        2015     69,467,537                 36312
#
#    Revenues Per Capita Business_1 Payment_Ye  total_paym  Subsidy Per Capita
# 0                 2163    Alameda       2019  6739083.67                 4.0
# 1                 1842    Alameda       2018  2549750.00                 1.0
# 2                 1792    Alameda       2017  5737500.00                 3.0
# 3                 1621    Alameda       2016  3476500.00                 2.0
# 4                 1543    Alameda       2015  4862000.00                 3.0
# 5                 1556    Alameda       2014  4009166.68                 2.0
# 6                 1528    Alameda       2013  3315000.00                 2.0
# 7                 1513    Alameda       2012  5581667.00                 3.0
# 8                 1914     Amador       2017   106250.01                 2.0
# 9                 1913     Amador       2015    21250.00                 0.0

# %%
# calculate the median income
df_2["Subsidy Per Capita"] = (df_2["total_paym"]//df_2["Estimated Population"])
df_2.head()

# %% [markdown]
# # Application of Linear Regression

# %%
# ================================================
# Build the model
# ================================================

# Training data
X = df_2.loc[:,["Revenues Per Capita"]]  # features matrix
y = df_2.loc[:,'total_paym']  # target (response) matix

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=100)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
sns.regplot(x='Revenues Per Capita', y='total_paym', data=df_2, ci=None, scatter_kws={'s':100, 'facecolor':'red'})
# Out:
# <AxesSubplot: xlabel='Revenues Per Capita', ylabel='total_paym'>

# %% [markdown]
# # Predicting test set result

# %%
y_pred = model.predict(X_test)

# Comparing the test values and the predicted values
comparison_df = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
comparison_df
# Out:
#           Actual     Predicted
# 121  18323146.69  1.264451e+06
# 355    590750.00  1.410279e+06
# 225   3096834.06  1.307031e+06
# 398    187000.00  1.157813e+06
# 129   1287750.00  1.539149e+06
# ..           ...           ...
# 84     416500.00  1.602831e+06
# 285   1083750.00  1.562512e+06
# 80     170000.00  1.297234e+06
# 284   1658916.67  1.513149e+06
# 234     68000.00  1.645411e+06
#
# [122 rows x 2 columns]

# %%
# Checking the residuals
residuals = y_test - y_pred
residuals
# Out:
# 121    1.705870e+07
# 355   -8.195286e+05
# 225    1.789803e+06
# 398   -9.708125e+05
# 129   -2.513994e+05
#            ...
# 84    -1.186331e+06
# 285   -4.787619e+05
# 80    -1.127234e+06
# 284    1.457675e+05
# 234   -1.577411e+06
# Name: total_paym, Length: 122, dtype: float64

# %%
# Comparing the test data and the predicted values with a scatter plot
sns.scatterplot(x=y_test, y = y_pred, s=140)
plt.xlabel('y_test data')
plt.ylabel('Predictions')

# The values seem to align linearly, which shows that the model is acceptable.
# Out:
# Text(0, 0.5, 'Predictions')

# %% [markdown]
# # per-capita EHR spending correlation with median income analysis

# %%
# ================================================
# Build the model
# ================================================

# Training data
X = df_2.loc[:,["Revenues Per Capita"]]  # features matrix
y = df_2.loc[:,'Subsidy Per Capita']  # target (response) matix

from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=100)

# Train the model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
sns.regplot(x='Revenues Per Capita', y='Subsidy Per Capita', data=df_2, ci=None, scatter_kws={'s':100, 'facecolor':'red'})
# Out:
# <AxesSubplot: xlabel='Revenues Per Capita', ylabel='Subsidy Per Capita'>

# %%
y_pred = model.predict(X_test)

# Comparing the test values and the predicted values
comparison_df = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
comparison_df
# Out:
#      Actual  Predicted
# 121     1.0   3.104099
# 355     9.0   2.419808
# 225     2.0   2.904293
# 398     2.0   3.604497
# 129     8.0   1.815086
# ..      ...        ...
# 84      2.0   1.516262
# 285     2.0   1.705458
# 80      0.0   2.950266
# 284     3.0   1.937092
# 234     1.0   1.316456
#
# [122 rows x 2 columns]

# %%
# Checking the residuals
residuals = y_test - y_pred
residuals
# Out:
# 121   -2.104099
# 355    6.580192
# 225   -0.904293
# 398   -1.604497
# 129    6.184914
#          ...
# 84     0.483738
# 285    0.294542
# 80    -2.950266
# 284    1.062908
# 234   -0.316456
# Name: Subsidy Per Capita, Length: 122, dtype: float64

# %%
# Comparing the test data and the predicted values with a scatter plot
sns.scatterplot(x=y_test, y = y_pred, s=140)
plt.xlabel('y_test data')
plt.ylabel('Predictions')

# The values seem to align linearly, which shows that the model is acceptable.
# Out:
# Text(0, 0.5, 'Predictions')
